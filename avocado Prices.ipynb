# %%
#importing the necessary libraries for plotting
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm

#importing numpy and panda
import numpy as np
import pandas as pd

#librariers to build models and checking accuracy
import sklearn
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from statsmodels.formula.api import ols

#library to split data
from sklearn.model_selection import train_test_split

#library for EDA
from scipy.stats import zscore

#Library for saving data
import pickle

#library for GridSearchCV 
from sklearn.model_selection import GridSearchCV

#library for error detection in regression models
from sklearn.metrics import mean_squared_error, mean_absolute_error

#libraries for regularisation
from sklearn.linear_model import Ridge,Lasso,RidgeCV,LassoCV

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('avocado.csv')
df.head(50)
# Out:
#     Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0          0.0  27-12-2015          1.33      64236.62  1036.74   54454.85
# 1          1.0  20-12-2015          1.35      54876.98   674.28   44638.81
# 2          2.0  13-12-2015          0.93     118220.22   794.70  109149.67
# 3          3.0  06-12-2015          1.08      78992.15  1132.00   71976.41
# 4          4.0  29-11-2015          1.28      51039.60   941.48   43838.39
# 5          5.0  22-11-2015          1.26      55979.78  1184.27   48067.99
# 6          6.0  15-11-2015          0.99      83453.76  1368.92   73672.72
# 7          7.0  08-11-2015          0.98     109428.33   703.75  101815.36
# 8          8.0  01-11-2015          1.02      99811.42  1022.15   87315.57
# 9          9.0  25-10-2015          1.07      74338.76   842.40   64757.44
# 10        10.0  18-10-2015          1.12      84843.44   924.86   75595.85
# 11        11.0  11-10-2015          1.28      64489.17  1582.03   52677.92
# 12        12.0  04-10-2015          1.31      61007.10  2268.32   49880.67
# 13        13.0  27-09-2015          0.99     106803.39  1204.88   99409.21
# 14        14.0  20-09-2015          1.33      69759.01  1028.03   59313.12
# 15        15.0  13-09-2015          1.28      76111.27   985.73   65696.86
# 16        16.0  06-09-2015          1.11      99172.96   879.45   90062.62
# 17        17.0  30-08-2015          1.07     105693.84   689.01   94362.67
# 18        18.0  23-08-2015          1.34      79992.09   733.16   67933.79
# 19        19.0  16-08-2015          1.33      80043.78   539.65   68666.01
# 20        20.0  09-08-2015          1.12     111140.93   584.63  100961.46
# 21        21.0  02-08-2015          1.45      75133.10   509.94   62035.06
# 22        22.0  26-07-2015          1.11     106757.10   648.75   91949.05
# 23        23.0  19-07-2015          1.26      96617.00  1042.10   82049.40
# 24        24.0  12-07-2015          1.05     124055.31   672.25   94693.52
# 25        25.0  05-07-2015          1.35     109252.12   869.45   72600.55
# 26        26.0  28-06-2015          1.37      89534.81   664.23   57545.79
# 27        27.0  21-06-2015          1.27     104849.39   804.01   76688.55
# 28        28.0  14-06-2015          1.32      89631.30   850.58   55400.94
# 29        29.0  07-06-2015          1.07     122743.06   656.71   99220.82
# 30        30.0  31-05-2015          1.23      95123.62   922.37   70469.69
# 31        31.0  24-05-2015          1.19     101470.91   680.27   71376.81
# 32        32.0  17-05-2015          1.43     109857.47  1150.55   81955.16
# 33        33.0  10-05-2015          1.26     120427.91  1420.43  102000.52
# 34        34.0  03-05-2015          1.20      59197.67   919.87   45490.05
# 35        35.0  26-04-2015          1.22      49585.46   875.65   35841.75
# 36        36.0  19-04-2015          1.19      49064.73   774.15   33941.51
# 37        37.0  12-04-2015          1.13      48364.29   864.27   30374.15
# 38        38.0  05-04-2015          1.16      47362.13   961.77   35577.66
# 39        39.0  29-03-2015          1.02      67799.08  1402.28   58623.22
# 40        40.0  22-03-2015          1.12      46346.85  2141.83   34313.56
# 41        41.0  15-03-2015          1.11      43045.79  2128.26   30447.17
# 42        42.0  08-03-2015          1.07      40507.36   795.68   30370.64
# 43        43.0  01-03-2015          0.99      55595.74   629.46   45633.34
# 44        44.0  22-02-2015          1.07      45675.05  1088.38   35056.13
# 45        45.0  15-02-2015          1.06      41567.62   986.66   30045.51
# 46        46.0  08-02-2015          0.99      51253.97  1357.37   39111.81
# 47        47.0  01-02-2015          0.99      70873.60  1353.90   60017.20
# 48        48.0  25-01-2015          1.06      45147.50   941.38   33196.16
# 49        49.0  18-01-2015          1.17      44511.28   914.14   31540.32
#
#        4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0     48.16     8696.87     8603.62       93.25         0.00  conventional
# 1     58.33     9505.56     9408.07       97.49         0.00  conventional
# 2    130.50     8145.35     8042.21      103.14         0.00  conventional
# 3     72.58     5811.16     5677.40      133.76         0.00  conventional
# 4     75.78     6183.95     5986.26      197.69         0.00  conventional
# 5     43.61     6683.91     6556.47      127.44         0.00  conventional
# 6     93.26     8318.86     8196.81      122.05         0.00  conventional
# 7     80.00     6829.22     6266.85      562.37         0.00  conventional
# 8     85.34    11388.36    11104.53      283.83         0.00  conventional
# 9    113.00     8625.92     8061.47      564.45         0.00  conventional
# 10   117.07     8205.66     7877.86      327.80         0.00  conventional
# 11   105.32    10123.90     9866.27      257.63         0.00  conventional
# 12   101.36     8756.75     8379.98      376.77         0.00  conventional
# 13   154.84     6034.46     5888.87      145.59         0.00  conventional
# 14   150.50     9267.36     8489.10      778.26         0.00  conventional
# 15   142.00     9286.68     8665.19      621.49         0.00  conventional
# 16   240.79     7990.10     7762.87      227.23         0.00  conventional
# 17   335.43    10306.73    10218.93       87.80         0.00  conventional
# 18   444.78    10880.36    10745.79      134.57         0.00  conventional
# 19   394.90    10443.22    10297.68      145.54         0.00  conventional
# 20   368.95     9225.89     9116.34      109.55         0.00  conventional
# 21   741.08    11847.02    11768.52       78.50         0.00  conventional
# 22   966.61    13192.69    13061.53      131.16         0.00  conventional
# 23  2238.02    11287.48    11103.49      183.99         0.00  conventional
# 24  4257.64    24431.90    24290.08      108.49        33.33  conventional
# 25  5883.16    29898.96    29663.19      235.77         0.00  conventional
# 26  4662.71    26662.08    26311.76      350.32         0.00  conventional
# 27  5481.18    21875.65    21662.00      213.65         0.00  conventional
# 28  4377.19    29002.59    28343.14      659.45         0.00  conventional
# 29    90.32    22775.21    22314.99      460.22         0.00  conventional
# 30    50.55    23681.01    23222.49      458.52         0.00  conventional
# 31    58.70    29355.13    28761.81      593.32         0.00  conventional
# 32    94.32    26657.44    26285.43      372.01         0.00  conventional
# 33   185.66    16821.30    16535.55      285.75         0.00  conventional
# 34   217.24    12570.51    12201.95      368.56         0.00  conventional
# 35    89.62    12778.44    12076.83      701.61         0.00  conventional
# 36    47.15    14301.92    13602.97      698.95         0.00  conventional
# 37    21.50    17104.37    16438.49      665.88         0.00  conventional
# 38    93.76    10728.94     9869.16      755.61       104.17  conventional
# 39    89.50     7684.08     7208.49      475.59         0.00  conventional
# 40   141.80     9749.66     9252.60      497.06         0.00  conventional
# 41    99.67    10370.69     9989.59      381.10         0.00  conventional
# 42   159.05     9181.99     8827.55      354.44         0.00  conventional
# 43   181.49     9151.45     8986.06      165.39         0.00  conventional
# 44   151.00     9379.54     9000.16      379.38         0.00  conventional
# 45   222.42    10313.03     9979.87      333.16         0.00  conventional
# 46   163.25    10621.54    10113.10      508.44         0.00  conventional
# 47   179.32     9323.18     9170.82      152.36         0.00  conventional
# 48   164.14    10845.82    10103.35      742.47         0.00  conventional
# 49   135.77    11921.05    11651.09      269.96         0.00  conventional
#
#       year  region
# 0   2015.0  Albany
# 1   2015.0  Albany
# 2   2015.0  Albany
# 3   2015.0  Albany
# 4   2015.0  Albany
# 5   2015.0  Albany
# 6   2015.0  Albany
# 7   2015.0  Albany
# 8   2015.0  Albany
# 9   2015.0  Albany
# 10  2015.0  Albany
# 11  2015.0  Albany
# 12  2015.0  Albany
# 13  2015.0  Albany
# 14  2015.0  Albany
# 15  2015.0  Albany
# 16  2015.0  Albany
# 17  2015.0  Albany
# 18  2015.0  Albany
# 19  2015.0  Albany
# 20  2015.0  Albany
# 21  2015.0  Albany
# 22  2015.0  Albany
# 23  2015.0  Albany
# 24  2015.0  Albany
# 25  2015.0  Albany
# 26  2015.0  Albany
# 27  2015.0  Albany
# 28  2015.0  Albany
# 29  2015.0  Albany
# 30  2015.0  Albany
# 31  2015.0  Albany
# 32  2015.0  Albany
# 33  2015.0  Albany
# 34  2015.0  Albany
# 35  2015.0  Albany
# 36  2015.0  Albany
# 37  2015.0  Albany
# 38  2015.0  Albany
# 39  2015.0  Albany
# 40  2015.0  Albany
# 41  2015.0  Albany
# 42  2015.0  Albany
# 43  2015.0  Albany
# 44  2015.0  Albany
# 45  2015.0  Albany
# 46  2015.0  Albany
# 47  2015.0  Albany
# 48  2015.0  Albany
# 49  2015.0  Albany

# %% [markdown]
# The data is the weekly 2018 retail scan data for National retail volume (units) and price. Retail scan data comes directly from retailers’ cash registers based on actual retail sales of Hass avocados.

# %%
#show all columns in dataframe
pd.set_option('display.max_columns', None)
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0             0.0  27-12-2015          1.33      64236.62  1036.74   54454.85
# 1             1.0  20-12-2015          1.35      54876.98   674.28   44638.81
# 2             2.0  13-12-2015          0.93     118220.22   794.70  109149.67
# 3             3.0  06-12-2015          1.08      78992.15  1132.00   71976.41
# 4             4.0  29-11-2015          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 16463         NaN         NaN           NaN           NaN      NaN        NaN
# 16464         NaN         NaN           NaN           NaN      NaN        NaN
# 16465         NaN         NaN           NaN           NaN      NaN        NaN
# 16466         NaN         NaN           NaN           NaN      NaN        NaN
# 16467         NaN         NaN           NaN           NaN      NaN        NaN
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0       48.16     8696.87     8603.62       93.25          0.0  conventional
# 1       58.33     9505.56     9408.07       97.49          0.0  conventional
# 2      130.50     8145.35     8042.21      103.14          0.0  conventional
# 3       72.58     5811.16     5677.40      133.76          0.0  conventional
# 4       75.78     6183.95     5986.26      197.69          0.0  conventional
# ...       ...         ...         ...         ...          ...           ...
# 16463     NaN         NaN         NaN         NaN          NaN           NaN
# 16464     NaN         NaN         NaN         NaN          NaN           NaN
# 16465     NaN         NaN         NaN         NaN          NaN           NaN
# 16466     NaN         NaN         NaN         NaN          NaN           NaN
# 16467     NaN         NaN         NaN         NaN          NaN           NaN
#
#          year  region
# 0      2015.0  Albany
# 1      2015.0  Albany
# 2      2015.0  Albany
# 3      2015.0  Albany
# 4      2015.0  Albany
# ...       ...     ...
# 16463     NaN     NaN
# 16464     NaN     NaN
# 16465     NaN     NaN
# 16466     NaN     NaN
# 16467     NaN     NaN
#
# [16468 rows x 14 columns]

# %% [markdown]
# We havde 14 columns to deal with
#
# We are given dataset of 16,468 avocados which we would split to test and train

# %% [markdown]
# Label is :
#
# • AveragePrice - the average price of a single avocado

# %% [markdown]
# features are :
#
# • Date - The date of the observation
#
# • type - conventional or organic
#
# • year - the year
#
# • Region - the city or region of the observation
#
# • Total Volume - Total number of avocados sold
#
# • 4046 - Total number of avocados with PLU 4046 sold
#
# • 4225 - Total number of avocados with PLU 4225 sold
#
# • 4770 - Total number of avocados with PLU 4770 sold

# %% [markdown]
# We would need to drop the unnecessry columns like Total Bags,Small Bags,Large Bags,XLarge Bags if accuracy is low later

# %% [markdown]
# # Checking columns with single unique values

# %%
#value counts of some  datas

print("type",df["type"].value_counts())

print(" ")
print("year",df["year"].value_counts())

print(" ")
print("region",df["region"].value_counts())
# Out:
# type conventional    1517
# Name: type, dtype: int64
#
# year 2015.0    1270
# 2016.0     247
# Name: year, dtype: int64
#
# region California             76
# Albany                 67
# BaltimoreWashington    65
# Boise                  65
# Boston                 62
# Atlanta                54
# PhoenixTucson          52
# BuffaloRochester       51
# Spokane                49
# Columbus               47
# NewYork                44
# Jacksonville           41
# Detroit                40
# SouthCentral           39
# SanDiego               38
# West                   36
# Tampa                  34
# Louisville             34
# Charlotte              31
# Portland               30
# Houston                29
# NorthernNewEngland     29
# WestTexNewMexico       27
# TotalUS                25
# Nashville              25
# Denver                 24
# SouthCarolina          24
# GrandRapids            23
# Chicago                23
# Pittsburgh             22
# RichmondNorfolk        21
# Orlando                21
# Syracuse               19
# HarrisburgScranton     19
# GreatLakes             18
# Midsouth               18
# MiamiFtLauderdale      17
# DallasFtWorth          17
# Roanoke                17
# Indianapolis           16
# StLouis                16
# RaleighGreensboro      16
# SanFrancisco           15
# HartfordSpringfield    13
# Philadelphia           13
# Northeast              12
# Plains                 12
# LasVegas               10
# Seattle                 9
# Southeast               9
# LosAngeles              3
# Name: region, dtype: int64

# %%
df.describe(include='all')
# Out:
#          Unnamed: 0        Date  AveragePrice  Total Volume          4046  \
# count   1517.000000        1517   1517.000000  1.517000e+03  1.517000e+03
# unique          NaN         104           NaN           NaN           NaN
# top             NaN  12-04-2015           NaN           NaN           NaN
# freq            NaN          34           NaN           NaN           NaN
# mean      26.995386         NaN      1.074990  1.601879e+06  6.464387e+05
# std       14.848287         NaN      0.188891  4.433143e+06  1.947614e+06
# min        0.000000         NaN      0.490000  3.875074e+04  4.677200e+02
# 25%       14.000000         NaN      0.980000  1.474700e+05  2.040034e+04
# 50%       29.000000         NaN      1.080000  4.027919e+05  8.175117e+04
# 75%       39.000000         NaN      1.190000  9.819751e+05  3.775785e+05
# max       51.000000         NaN      1.680000  4.465546e+07  1.893304e+07
#
#                 4225          4770    Total Bags    Small Bags    Large Bags  \
# count   1.517000e+03  1.517000e+03  1.517000e+03  1.517000e+03  1.517000e+03
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    6.114375e+05  5.040550e+04  2.935974e+05  2.487736e+05  4.264205e+04
# std     1.672906e+06  1.377812e+05  7.579765e+05  6.474765e+05  1.182157e+05
# min     1.783770e+03  0.000000e+00  3.311770e+03  3.311770e+03  0.000000e+00
# 25%     4.147606e+04  9.112500e+02  3.620689e+04  2.972722e+04  5.407400e+02
# 50%     1.186649e+05  7.688170e+03  7.397906e+04  6.237569e+04  5.044350e+03
# 75%     4.851503e+05  2.916730e+04  1.576097e+05  1.461994e+05  2.926767e+04
# max     1.895648e+07  1.381516e+06  6.736304e+06  5.893642e+06  1.121076e+06
#
#           XLarge Bags          type         year      region
# count     1517.000000          1517  1517.000000        1517
# unique            NaN             1          NaN          51
# top               NaN  conventional          NaN  California
# freq              NaN          1517          NaN          76
# mean      2181.771074           NaN  2015.162821         NaN
# std       7455.712144           NaN     0.369324         NaN
# min          0.000000           NaN  2015.000000         NaN
# 25%          0.000000           NaN  2015.000000         NaN
# 50%          0.000000           NaN  2015.000000         NaN
# 75%        401.480000           NaN  2015.000000         NaN
# max     108072.790000           NaN  2016.000000         NaN

# %% [markdown]
# Observation
#
# 1.Eventhough we have 16468 columns in dataset, only 1517 datas are present, so we will need to remove the rest
#
# 2.The date has 104 unique values, the region has 51 unique values
#
# 3.Type has only 1 unique value
#
# 4.Outliers can be seen from the deviation from mean and median in all the columns
#
# 5.Unnamed is an unnecessary column which can be dropped
#
# 6.Date is not in a format we can use, hence need to convert to different columns
#
# 7.Both numerical and categorical values are present, hence eda has to be done on both
#
# 8.Lable is numerical so our modelling will be through regression techniques

# %%
df.shape
# Out:
# (16468, 14)

# %% [markdown]
# # checking for null values and removing the empty rows

# %%
#removing duplicate values
df = df.drop_duplicates()
len(df)
# Out:
# 1518

# %%
df.isnull().values.any()
# Out:
# True

# %%
#Checking null values
df.isnull().sum()
# Out:
# Unnamed: 0      1
# Date            1
# AveragePrice    1
# Total Volume    1
# 4046            1
# 4225            1
# 4770            1
# Total Bags      1
# Small Bags      1
# Large Bags      1
# XLarge Bags     1
# type            1
# year            1
# region          1
# dtype: int64

# %%
# Drop rows with any empty cells
df.dropna(
    axis=0,
    how='any',
    thresh=None,
    subset=None,
    inplace=True
)

# %%
#Checking null values
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %% [markdown]
# The dataframe doesnt contain empty rows anymore

# %% [markdown]
# # dropping columns which we observed in describe

# %% [markdown]
# #Since Type one unique value, dropping it
# df=df.drop(columns=["type"])

# %%
#dropping unnamed
df=df.drop(columns=["Unnamed: 0"])

# %%
#dropping year
df=df.drop(columns=["year"])

# %% [markdown]
# # making date into usable format

# %%
#extracting Date into more usable format, since year column is already present we can drop it
df['Date'] = pd.to_datetime(df['Date'])
print (df['Date'].dtype)
# Out:
# datetime64[ns]

# %%
#splitting into month and date
df['month'] = df['Date'].dt.month
df['day'] = df['Date'].dt.day

# %%
## Now we can drop Date as it is of no use
df.drop(["Date"], axis = 1, inplace = True)
df
# Out:
#       AveragePrice  Total Volume      4046       4225      4770  Total Bags  \
# 0             1.33      64236.62   1036.74   54454.85     48.16     8696.87
# 1             1.35      54876.98    674.28   44638.81     58.33     9505.56
# 2             0.93     118220.22    794.70  109149.67    130.50     8145.35
# 3             1.08      78992.15   1132.00   71976.41     72.58     5811.16
# 4             1.28      51039.60    941.48   43838.39     75.78     6183.95
# ...            ...           ...       ...        ...       ...         ...
# 1512          1.39     190846.01  57529.11   56366.66  17531.78    59418.46
# 1513          1.51     178235.75  43325.87   52189.61  19419.57    63300.70
# 1514          1.48     178410.82  46364.75   52893.38  16736.92    62415.77
# 1515          1.47     189131.52  54110.79   53593.58  17495.42    63931.73
# 1516          1.43     182978.30  43116.41   54193.42  16563.91    69104.56
#
#       Small Bags  Large Bags  XLarge Bags          type     region  month  day
# 0        8603.62       93.25         0.00  conventional     Albany     12   27
# 1        9408.07       97.49         0.00  conventional     Albany     12   20
# 2        8042.21      103.14         0.00  conventional     Albany     12   13
# 3        5677.40      133.76         0.00  conventional     Albany      6   12
# 4        5986.26      197.69         0.00  conventional     Albany     11   29
# ...          ...         ...          ...           ...        ...    ...  ...
# 1512    48823.53    10354.65       240.28  conventional  Charlotte     10   16
# 1513    54704.14     8596.56         0.00  conventional  Charlotte      9   10
# 1514    53332.61     8258.16       825.00  conventional  Charlotte      2   10
# 1515    55653.47     8278.26         0.00  conventional  Charlotte      9   25
# 1516    57456.21    11648.35         0.00  conventional  Charlotte      9   18
#
# [1517 rows x 13 columns]

# %% [markdown]
# # splitting the numerical datas

# %%
#finding numerical datas
df.select_dtypes(include=["number"]).columns
# Out:
# Index(['AveragePrice', 'Total Volume', '4046', '4225', '4770', 'Total Bags',
#        'Small Bags', 'Large Bags', 'XLarge Bags', 'month', 'day'],
#       dtype='object')

# %%
num=df[{'AveragePrice', 'Total Volume', '4046', '4225', '4770'
       , 'month', 'day',"Total Bags","Small Bags","Large Bags","XLarge Bags"}]
num
# Out:
#           4770  AveragePrice  Total Volume  Total Bags  month  Large Bags  \
# 0        48.16          1.33      64236.62     8696.87     12       93.25
# 1        58.33          1.35      54876.98     9505.56     12       97.49
# 2       130.50          0.93     118220.22     8145.35     12      103.14
# 3        72.58          1.08      78992.15     5811.16      6      133.76
# 4        75.78          1.28      51039.60     6183.95     11      197.69
# ...        ...           ...           ...         ...    ...         ...
# 1512  17531.78          1.39     190846.01    59418.46     10    10354.65
# 1513  19419.57          1.51     178235.75    63300.70      9     8596.56
# 1514  16736.92          1.48     178410.82    62415.77      2     8258.16
# 1515  17495.42          1.47     189131.52    63931.73      9     8278.26
# 1516  16563.91          1.43     182978.30    69104.56      9    11648.35
#
#       day       4225      4046  XLarge Bags  Small Bags
# 0      27   54454.85   1036.74         0.00     8603.62
# 1      20   44638.81    674.28         0.00     9408.07
# 2      13  109149.67    794.70         0.00     8042.21
# 3      12   71976.41   1132.00         0.00     5677.40
# 4      29   43838.39    941.48         0.00     5986.26
# ...   ...        ...       ...          ...         ...
# 1512   16   56366.66  57529.11       240.28    48823.53
# 1513   10   52189.61  43325.87         0.00    54704.14
# 1514   10   52893.38  46364.75       825.00    53332.61
# 1515   25   53593.58  54110.79         0.00    55653.47
# 1516   18   54193.42  43116.41         0.00    57456.21
#
# [1517 rows x 11 columns]

# %%
#finding categorical datas
df.select_dtypes(exclude=["number"]).columns
# Out:
# Index(['type', 'region'], dtype='object')

# %%
cat=df[['region','type']]
cat
# Out:
#          region          type
# 0        Albany  conventional
# 1        Albany  conventional
# 2        Albany  conventional
# 3        Albany  conventional
# 4        Albany  conventional
# ...         ...           ...
# 1512  Charlotte  conventional
# 1513  Charlotte  conventional
# 1514  Charlotte  conventional
# 1515  Charlotte  conventional
# 1516  Charlotte  conventional
#
# [1517 rows x 2 columns]

# %%
#with type
sns.barplot(x="type",y="AveragePrice",data=df)
# Out:
# <AxesSubplot:xlabel='type', ylabel='AveragePrice'>

# %% [markdown]
# There is only conventional and no organic avocado

# %%
group_country_orders = df.groupby('region')['AveragePrice'].count().sort_values()

# plot number of orders in each country 
plt.subplots(figsize=(15,8))
group_country_orders.plot(kind='barh', fontsize=12)
plt.xlabel('AveragePrice', fontsize=12)
plt.ylabel('region', fontsize=12)
plt.title('average price for different Countries', fontsize=12)
plt.show()

# %% [markdown]
# It can be seen the maximum average price is obtained in California, then followed by albany

# %% [markdown]
# # EDA on categorical data

# %%
#label encoding on Attrition(label)
from sklearn.preprocessing import LabelEncoder
lab_enc=LabelEncoder()
df=df.apply(LabelEncoder().fit_transform)

# %% [markdown]
# # EDA on continous data

# %%
#plotting the numeric data

plt.figure(figsize=(15,50))
graph=1

for column in num:
    if graph<=30:
        ax=plt.subplot(10,3,graph)
        sns.boxplot(num[column],orient='v')
        plt.xlabel(column,fontsize=10)
    graph+=1
    
plt.show()

# %% [markdown]
# Large number of outliers can be seen on all the features

# %%
#Using zscore
import numpy as np
from scipy.stats import zscore

z=np.abs(zscore(num))
threshold=3
df_new=df[(z<4).all(axis=1)]

print("columns before applying zscore: ",len(df))
print("columns after applying zscore: ",len(df_new))
# Out:
# columns before applying zscore:  1517
# columns after applying zscore:  1471

# %%
df=df_new

#checking for outliers
df.hist(figsize=(35,20),bins = 15)
plt.title("Features Distribution")
plt.show()

# %% [markdown]
# Large number of outliers are removed

# %%
# reducing skewness
num=df[{'AveragePrice', 'Total Volume', '4046', '4225', '4770', 'month', 'day',"Total Bags","Small Bags","Large Bags","XLarge Bags"}]
num.skew()
# Out:
# 4770            0.012366
# AveragePrice   -0.141405
# Total Volume    0.013560
# Total Bags      0.008140
# month           0.100475
# Large Bags      0.085623
# day             0.045105
# 4225            0.013708
# 4046            0.018491
# XLarge Bags     1.098735
# Small Bags      0.008919
# dtype: float64

# %%
num_skew=('AveragePrice', 'Total Volume', '4046', '4225', '4770', 'month', 'day',"Total Bags","Small Bags","Large Bags","XLarge Bags")
for col in num_skew:
    if num.skew().loc[col]>0.55:
        df[col]=np.log1p(df[col])

# %%
df.skew()
# Out:
# AveragePrice   -0.141405
# Total Volume    0.013560
# 4046            0.018491
# 4225            0.013708
# 4770            0.012366
# Total Bags      0.008140
# Small Bags      0.008919
# Large Bags      0.085623
# XLarge Bags     0.299982
# type            0.000000
# region          0.300220
# month           0.100475
# day             0.045105
# dtype: float64

# %%
#plotting the numeric data

plt.figure(figsize=(15,50))
graph=1

for column in num:
    if graph<=30:
        ax=plt.subplot(10,3,graph)
        sns.boxplot(num[column],orient='v')
        plt.xlabel(column,fontsize=10)
    graph+=1
    
plt.show()

# %%
df.hist(figsize=(35,20),bins = 15)
plt.title("Features")
plt.show()

# %% [markdown]
# The skewness from the numerical feature columns are also removed

# %% [markdown]
# EDA completed on numerical data

# %% [markdown]
# # Checking for relationships
# Checking multicollineairty with vif and heatmap

# %%
#vif
x=num.drop(columns=["AveragePrice"])
y=df["AveragePrice"]

import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

scaler=StandardScaler()
x_scaler=scaler.fit_transform(x)

vif=pd.DataFrame()
vif["quality"]=[variance_inflation_factor(x_scaler,i) for i in range(x_scaler.shape[1])]
vif["feature"]=x.columns
vif
# Out:
#      quality       feature
# 0   2.327602          4770
# 1  24.768972  Total Volume
# 2  45.545735    Total Bags
# 3   1.021433         month
# 4   2.942361    Large Bags
# 5   1.009463           day
# 6   8.899722          4225
# 7   5.458590          4046
# 8   1.509677   XLarge Bags
# 9  36.263968    Small Bags

# %%
from matplotlib.pyplot import subplot

data_corr=df.corr()
plt.figure(figsize=(20,15))
ax=subplot(111)
sns.heatmap(data_corr,ax=ax,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # understanding relationship between features and label

# %%
#understanding the relationship between independent variable with label
data_corr=df.corr()
data_corr["AveragePrice"].sort_values(ascending=False)
# Out:
# AveragePrice    1.000000
# day             0.093272
# month           0.063801
# XLarge Bags    -0.074612
# 4225           -0.139439
# Small Bags     -0.142163
# Total Bags     -0.195177
# region         -0.217202
# Large Bags     -0.252238
# 4770           -0.257792
# Total Volume   -0.356178
# 4046           -0.554395
# type                 NaN
# Name: AveragePrice, dtype: float64

# %% [markdown]
# # Understanding each of the numerical data given through plots

# %% [markdown]
# Date - The date of the observation
#
# • type - conventional or organic
#
# • Region - the city or region of the observation
#
# • Total Volume - Total number of avocados sold
#
# • 4046 - Total number of avocados with PLU 4046 sold
#
# • 4225 - Total number of avocados with PLU 4225 sold
#
# • 4770 - Total number of avocados with PLU 4770 sold

# %%
#with total volume
plt.scatter(df["Total Volume"],df["AveragePrice"])

# %% [markdown]
#    The average price varies with total volume. When the total volume sold was between 1-900, the average price can be seen to be between 40 and 80.
#
#    But when the volume increased that 900, then the average price has fallen

# %%
#relationships

plt.figure(figsize=(16,10))
sns.lineplot(x="month",y="AveragePrice",hue='type',data=df)
plt.show()

# %% [markdown]
# We can see the maximum average price obtained is in the month of November

# %%
#visualising the relationship- scatter plot 
plt.figure(figsize=(20,30),facecolor='white')
plotnumber=1

for column in x:
    if plotnumber<=15:
        X=plt.subplot(5,3,plotnumber)
        plt.scatter(x[column],y)
        plt.xlabel(column,fontsize=20)
        plt.ylabel('Average price',fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# # Splitting data

# %%
#scaling
scalar=StandardScaler()
x_scaled=scalar.fit_transform(x)

#splitting data
x_train, x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.25,random_state=10)

# %%
y_train.head()
# Out:
# 1066    47
# 624     55
# 831     71
# 848     41
# 151     67
# Name: AveragePrice, dtype: int64

# %% [markdown]
# # Finding best random state

# %%
df
# Out:
#       AveragePrice  Total Volume  4046  4225  4770  Total Bags  Small Bags  \
# 0               81            71    54   506    68          41          46
# 1               83            35    11   413    92          58          68
# 2               41           294    22   742   194          34          39
# 3               56           152    61   625   112           8           7
# 4               76            27    41   406   115          12          10
# ...            ...           ...   ...   ...   ...         ...         ...
# 1512            87           501   626   521  1021         602         631
# 1513            99           468   527   485  1056         644         693
# 1514            96           469   560   493  1007         637         682
# 1515            95           495   604   495  1019         655         701
# 1516            91           485   524   502   999         710         714
#
#       Large Bags  XLarge Bags  type  region  month  day
# 0             78     0.000000     0       0     11   26
# 1             82     0.000000     0       0     11   19
# 2             86     0.000000     0       0     11   12
# 3            107     0.000000     0       0      5   11
# 4            143     0.000000     0       0     10   28
# ...          ...          ...   ...     ...    ...  ...
# 1512         769     5.676754     0       7      9   15
# 1513         726     0.000000     0       7      8    9
# 1514         716     5.963579     0       7      1    9
# 1515         717     0.000000     0       7      8   24
# 1516         799     0.000000     0       7      8   17
#
# [1471 rows x 13 columns]

# %%
maxAccu=0
maxRS=0

for i in range(1,200):
    x_train, x_test,y_train, y_test=train_test_split(x_scaled,y,test_size=.25,random_state=i)
    rf=RandomForestRegressor()
    rf.fit(x_train,y_train)
    predrf=rf.predict(x_test)
    r2=r2_score(y_test,predrf)
    if r2>maxAccu:
        maxr2=r2
        maxRS=i

print("Best r2 score is", maxr2,"on Random State",maxRS)
# Out:
# Best r2 score is 0.7925442010294608 on Random State 199

# %% [markdown]
# We found best random_state value as 80.2% .We will create our train_test split using the random_state(199)

# %%
scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)      
x_scaled
# Out:
# array([[-1.56510971, -1.55940422, -1.63165496, ..., -1.5972806 ,
#         -0.71676979, -1.61961783],
#        [-1.5088058 , -1.64379885, -1.59172503, ..., -1.69786389,
#         -0.71676979, -1.56795962],
#        [-1.26951417, -1.03662636, -1.6480967 , ..., -1.67213328,
#         -0.71676979, -1.63605454],
#        ...,
#        [ 0.63778088, -0.62637468, -0.23175868, ..., -0.41367267,
#          1.11660204, -0.12622596],
#        [ 0.66593284, -0.565423  , -0.18947994, ..., -0.31075024,
#         -0.71676979, -0.08161205],
#        [ 0.61901291, -0.58886595, -0.06029488, ..., -0.49788193,
#         -0.71676979, -0.05108675]])

# %%
x_train, x_test,y_train, y_test=train_test_split(x_scaled,y,test_size=.2,random_state=199)

# %%
#Linear Regression
from sklearn.linear_model import LinearRegression

LR=LinearRegression()
LR.fit(x_train,y_train)
predlr=LR.predict(x_test)
print("r2 score of LinearRegression model is",r2_score(y_test,predlr))
# Out:
# r2 score of LinearRegression model is 0.4151675395534554

# %%
#DecisionTreeClassifier

dt=DecisionTreeRegressor()
dt.fit(x_train,y_train)
predlr=dt.predict(x_test)
print("r2 score of DecisionTreeRegressor model is",r2_score(y_test,predlr))
# Out:
# r2 score of DecisionTreeRegressor model is 0.5471677718082228

# %%
#Random forest regressor
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
predlr=rf.predict(x_test)
print("r2 score of RandomForestRegressor model is",r2_score(y_test,predlr))
# Out:
# r2 score of RandomForestRegressor model is 0.8022602477035519

# %%
#cross validation
#Finding overfitting
from sklearn.model_selection import cross_val_score
from sklearn import linear_model
import statsmodels.api

scr1=cross_val_score(LR,x,y,cv=5)
print("Cross validation score of Linear Regression model :", scr1.mean())

scr2=cross_val_score(dt,x,y,cv=5)
print("Cross validation score of Decision Tree model :", scr2.mean())

scr3=cross_val_score(rf,x,y,cv=5)
print("Cross validation score of Random Forest model :", scr3.mean())
# Out:
# Cross validation score of Linear Regression model : 0.14911551599056544
# Cross validation score of Decision Tree model : -0.2978049734214232
# Cross validation score of Random Forest model : 0.15947144320216874

# %% [markdown]
# # Reason for selecting the model

# %% [markdown]
# The least difference between r2 score and cross validation score is seen in Random Forest Model
#
# Hence we will perform hyper parameter tuning in it

# %% [markdown]
# # hyperparameter tuning

# %%
#RandomForestRegressor
paramters={'n_estimators':[2,4,5,6,8],
           'min_samples_split':[2,3,4],
           'min_samples_leaf':[2,3,4],
           'max_leaf_nodes':[2,3,4],
           'max_features':['auto','sqrt','log2'],   
}

# %%
GCV=GridSearchCV(RandomForestRegressor(),paramters,cv=6)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=6, estimator=RandomForestRegressor(),
#              param_grid={'max_features': ['auto', 'sqrt', 'log2'],
#                          'max_leaf_nodes': [2, 3, 4],
#                          'min_samples_leaf': [2, 3, 4],
#                          'min_samples_split': [2, 3, 4],
#                          'n_estimators': [2, 4, 5, 6, 8]})

# %%
GCV.best_params_
# Out:
# {'max_features': 'auto',
#  'max_leaf_nodes': 4,
#  'min_samples_leaf': 3,
#  'min_samples_split': 2,
#  'n_estimators': 6}

# %%
mod=RandomForestRegressor(n_estimators=6,max_leaf_nodes=4,min_samples_leaf=3,min_samples_split=2,max_features='auto')

# %%
mod.fit(x_train,y_train)
pred=mod.predict(x_test)
print(r2_score(y_test,pred)*100)
# Out:
# 48.98762306373381

# %%
randomforest=RandomForestRegressor()
randomforest.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
# # Saving of model

# %%
#saving RandomForestRegressor model
RandomForestRegressor_model=RandomForestRegressor()
RandomForestRegressor_model.fit(x_train,y_train)

filename='finalized_model.pickle'
pickle.dump(RandomForestRegressor_model,open(filename,'wb'))

# %%
#Adjusted R2
RandomForestRegressor_model.score(x_train,y_train)
# Out:
# 0.9692990410796811

# %%
y_pred=RandomForestRegressor_model.predict(x_test)

# %%
plt.scatter(y_test,y_pred)
plt.xlabel('Actual chance of admission')
plt.ylabel('predicted chance of admission')
plt.title('actual vs model predicted')
plt.show()

# %% [markdown]
# # Prediction

# %%
#prediction using the saved model
loaded_model=pickle.load(open(filename,'rb'))
a=loaded_model.predict(scaler.transform([[14,69759.01,1028.03,59313.12,150.5,9267.36,8489.1,778.26,0,2015]]))
a
# Out:
# array([64.38])

# %% [markdown]
# #  Model evaluation

# %%
y_predict=RandomForestRegressor_model.predict(x_test)

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 6.7888813559322045

# %%
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 9.217043571741963

# %% [markdown]
# The mean abosolute error is 6

# %% [markdown]
# # Regularisation

# %%
lasscv=LassoCV(alphas=None, max_iter=1000,normalize=True)
lasscv.fit(x_train,y_train)

#best alpha parameter
alpha=lasscv.alpha_

lasso_reg=Lasso(alpha)
lasso_reg.fit(x_train,y_train)

lasso_reg.score(x_test,y_test)
# Out:
# 0.41513699884206967

# %%
ridgecv=RidgeCV(alphas=np.arange(0.001,0.1,0.01),normalize=True)
ridgecv.fit(x_train,y_train)

ridgecv.alpha_
# Out:
# 0.001

# %%
ridge_model=Ridge(alpha=ridgecv.alpha_)
ridge_model.fit(x_train,y_train)

ridge_model.score(x_test,y_test)
# Out:
# 0.4151668630782185
